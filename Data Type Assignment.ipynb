# %% [markdown]
# Name             : MANISH KUMAR
# Email            : mtktpulsar@gmail.com
# Assignmennt name : DATA TYPE AND STRUCTURES
# Drive Link       :
# Github Link      :

# %% [markdown]
# ## Theory Question

# %% [markdown]
# # Data Type and structure
# **Q1. what are data structure and why are they important?**
# -Data structures are specialized formats for orgnizing, storing and accessing collections of data.
# It helps in manipulating information in an efficient ways on the basis of data characteristics and its use.
#
# **Q2. Explain the difference between immutable and mutable data types with example.**
# - Immutable data Types:
#   In these types of data structure, no data can be either replaced,changed and it can only be accessed.
#   Ex- Tuples

# %%
a = (10,20,30,"ramesh","mahesh")
type(a)
# Out:
# tuple

# %%
a[-1] = "manish" # unable to replace mahesh at index no. (-1) with "manish". So we can say Tuple is an immutable data type.
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-abf2325a282f> in <cell line: 1>()
# ----> 1 a[-1] = "manish"
#       2 a
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# - Mutable Data Types:
#   In these types of data structure, any piece of data can be either replaced,changed or updated with different piece of data. Ex- List, set, dictionary and string.
#   ex-

# %%
a = [10,20,30,"ramesh","mahesh"]
a
# Out:
# [10, 20, 30, 'ramesh', 'mahesh']

# %%
type(a)
# Out:
# list

# %%
a[-1] = "kalki" # we are able to replace mahesh at index no. (-1) with "kalki". So we can say list is an immutable data type.
a
# Out:
# [10, 20, 30, 'ramesh', 'kalki']

# %% [markdown]
# **Q3. What are the main difference between Lists and Tuples in python?**
# - List:
#   A. It is mutable data type
#   B. It has the collections of heterogeneous data types
#   C. its elements can be accessed, replaced, removed or updated
#   D. It is represented by symbol as []
#
# - Tuples:
#   A. It is immutable data type
#   B. its elements can be only accessed and niteher replaced, removed or updated like in the lists
#   C. It is represented by symbol as ()
# **Q4. Describe how dictionary store data**
#  - Dictionary store data in a pair of keys and values.
#    It uses {} as symbol to store pair of keys and values.
#    Ex-

# %%
a = {10 : "ram",20 : "shyam",30 : 'ganesh'}
type(a)
# Out:
# dict

# %%
a
# Out:
# {10: 'ram', 20: 'shyam', 30: 'ganesh'}

# %%
a[10]
# Out:
# 'ram'

# %% [markdown]
# **Q5. Why might you use a set instead of list in python?**
#      - Although Set and list both share similar characteristics in terms of
#        mutability, but list stores orderly and heterogenous elements which can be accessed from any index throughout the list.
#
#        ex- helpfull, in stoing heterogenous data, easy indexing
#
#         whereas, set has unorderly and unique collection of elements which can't be accessed from any index throught the set.
#
#         ex- helpful, in comparison-difference,union,symmetary and intersection of data.
#
# **Q6. What is string in python and how is it different from a list?**
#      - **string** is a sequence of characters.
#        It can be accessed by indexing
#        Two strings can be either merged together.
#        All the strings uses symbol as " "
#        It can't grow like list sice it is fixed.
#     -  List is a orderly collection of heterogenous elements
#        It uses [] to store data.
#        List can dynamically grow or shrink by adding or removing the elements
#
# **Q7.  How do tuples ensure data integrity in python?**
#    -  Tuples are immutable, it means once its created its values can't be - -
#       removed or replaced. Now one can only access the data through indexing.
#       this phenomena ensures the data integrity in python.
#
# **Q8.**  **What is a hash table and how does it relate to dictionary in python?**  -
#
#
#
#
#
#
#
# **Q9. Can lists contain different data types in python?**
#    - yes, lists can contain different data types in python.
#
# **Q10. Explain why strings are immutable in python?**
#     - Strings are immutable since it holds meaning, if it becomes mutable then
#       the value will become meaningless.
#       It handls text mostly like sentence, message, paragraph which cant be chenged or alterd as it will destroy the meaning it holds originally.
#
# **Q11.  What advantages do dictionaries offer over lists for certain task?**
#     -  Disctionaries store data in a pair of key and value so if you want to
#        find the valu of any key just access the key through indeing and you will get value as well.
#        **whereas,** in list data is not stored as a pair of key and value instead in a ordered form so you can access only one type of data with respect to dictionary(two different data set stored at once together) and can be accessed together also.
#
# **Q12.   Describe a scenario where using a tuple would be preferable over a list.**
#      - Scenario-1st:
#        "Hotel Marriott wants to create a record of employee and want to access it later as required."

# %%
Emp_Name = ("manish","rakesh","santosh","rahul")
Emp_qlf = ("MA","BA","CA","DS")
emp = (Emp_Name + Emp_qlf)
emp
# Out:
# ('manish', 'rakesh', 'santosh', 'rahul', 'MA', 'BA', 'CA', 'DS')

# %%
emp["manish"] = "rachna" # data inside a tuple can't be change >> it makes the Employee records secured from alteration
emp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-9b72c099d3fb> in <cell line: 1>()
# ----> 1 emp["manish"] = "rachna"
#       2 emp
#
# TypeError: 'tuple' object does not support item assignment

# %%
lis = [("manish","rakesh","santosh","rahul"),("MA","BA","CA","DS")]
lis
# Out:
# [('manish', 'rakesh', 'santosh', 'rahul'), ('MA', 'BA', 'CA', 'DS')]

# %%
lis[0] = "haule_haule" # If employee record is stored in list instead of tuple then data in list can be easily alterd as you see below result.
lis
# Out:
# ['haule_haule', ('MA', 'BA', 'CA', 'DS')]

# %%
# So here, for storing critical employee data tuples are more preferable over the list due to tuples feature of "immutability".

# %% [markdown]
# Q13. How do sets handle duplicate values in python.
#     - Sets are unique and unorderly collection of data.
#       for EX-

# %%
set1 = {1,2,1,2,1,2,3,4,3,5,6,5,6} # a repetation of element is there in set1 >> but when executed it returns only unique values of a particular elements, as seen below.
set1
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Q14. How does the "in" keyword work differently for the list and dictionaries?

# %%
lis = [1,"mahesh","rakesh",1.2]
lis
# Out:
# [1, 'mahesh', 'rakesh', 1.2]

# %%
1.2 in lis # Here "in" returns the that particular element is available in the entire list or not
# Out:
# True

# %%
dic = {"mango" : 20,"potato" : 40, "beetroot" : 30}
dic
# Out:
# {'mango': 20, 'potato': 40, 'beetroot': 30}

# %%
"mango" in dic #Here "in" returns the that particular "key" only and not the "value" it holds is available in the entire dictionary or not.
# Out:
# True

# %% [markdown]
# Q15.  Can you modify the elements of a tuple? Explain why and why not?
#     - We can't modify the elements of a tuple, because tuples are designed for the purpose to handle sensitive data such as - recordsof company, finance data of previous years, employee data etc. These all needs security from alteration and modification.
#      so these inbuilt feature of immutability exist in python itself so we can't modify the tuple data.
#
# Q16. What is a nested dictionary and give an example of its use case?
#     -  Dictionary within dictionaries is called as nested dictionary.
#     -  Ex-
#     -  There is a college runs various courses and want to store different      course details at one place so that it can be accessed at any given point of time easily.
#        For Ex-

# %%
courses = {'php' : {'duration' : '12 months', 'fees' : 12000, 'teacher' : 'himansu'}, 'java' : {'duration' : '11 months', 'fees' : 1000, 'teacher' : 'amansu'}, 'ds' :{'duration' : '32 months', 'fees' : 20000, 'teacher' : 'rmansu'}}
courses
# Out:
# {'php': {'duration': '12 months', 'fees': 12000, 'teacher': 'himansu'},
#  'java': {'duration': '11 months', 'fees': 1000, 'teacher': 'amansu'},
#  'ds': {'duration': '32 months', 'fees': 20000, 'teacher': 'rmansu'}}

# %%
print(courses['java'])
# Out:
# {'duration': '11 months', 'fees': 1000, 'teacher': 'amansu'}

# %%
for k,v in courses.items():
  print(k,v['duration'],v['teacher']) # so we can access and orgnize a large versatile types of data by using dictionary in python
# Out:
# php 12 months himansu
# java 11 months amansu
# ds 32 months rmansu

# %% [markdown]
# **Q17.  Describe the time complexity of accessing elements in dictionary.**
#     -
#
#
#
#
#
#
#
#
# **Q18.  In what situations lists prefered over dictionary?**
#      - Lists are prefered over dictionaries while performing ordered operations.
#      - Lists are also usefull when manipulating string through indexing.
#
# Q19.  Why are dictionary considered unordered and how does that affect data
#       retrieval? **bold text**
#     - Dictionary is unordered because there is not any fixed index available as in the list. In dictionary data is stored as a pair of keys and values and elements(values) are accessed by calling keys of the dictionary only and not by calling values.
#      that's why considered are unordered.
#
#      It affects data retrieval:  if you wat to find any elements stored in dictionary then unlike list instead of index no. you have to pass either key name or index of key to access the particular values associated with that particular keys.
#
# Q20.  Explain the digfference between a list and a dictionary in terms of data
#       retrieval.
#     - List data retrieval:
#     - A. data can be accessed by using exact index no.
#     - B. data can be accessed either from right or left(revers) side by indexing.
#     - C. data can be accessed stepwise as well.
#
#    -  Dictionary data retrieval:
#    -  A. Data can be accessed only through keys and not values
#    -  B. data can be indexed but only on keys and not values

# %% [markdown]
# ##Practical Question

# %% [markdown]
# # Data Types and Structures

# %%
#q1. write a code to ccreate a string with your name and print it

# %%
name = "manish"
print(name)
# Out:
# manish

# %%
#q2. write a code to find the length of the string "hello world"

# %%
a = "hello world"
len(a)
# Out:
# 11

# %%
#q3. write a code to slice the first three characters from the "python programming"

# %%
a = "python programming"
a[0:3]
# Out:
# 'pyt'

# %%
#q4. write a code to convert the string "hello" to uppercase

# %%
a = "hello"
a.upper()
# Out:
# 'HELLO'

# %%
#q5. write a code to replace the word "apple" with "orange" in the string "i like apple"

# %%
x = "i like apple"
x
# Out:
# 'i like apple'

# %%
x.replace("apple","orange")
# Out:
# 'i like orange'

# %%
#q6. write a code to create a list with numbers 1 to 5 and print it

# %%
lis = [1,2,3,4,5]
print(lis)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q7. write a code to append the number 10 to the list[1,2,3,4]

# %%
lis1 = [1,2,3,4]
lis1
# Out:
# [1, 2, 3, 4]

# %%
lis1.append(10)
lis1
# Out:
# [1, 2, 3, 4, 10]

# %%
#Q8. write a code to remove number 3 from the list[1,2,3,4,5]

# %%
lis2 = [1,2,3,4,5]
lis2
# Out:
# [1, 2, 3, 4, 5]

# %%
lis2.pop(-3)
lis2
# Out:
# [1, 2, 4, 5]

# %%
#Q9. write a code to access second element in the list ["a","b","c","d"]

# %%
lis = ["a","b","c","d"]
lis
# Out:
# ['a', 'b', 'c', 'd']

# %%
lis[1]
# Out:
# 'b'

# %%
#Q10. write a code to reverse the list[10,20,30,40,50]

# %%
lis1 = [10,20,30,40,50]
lis1
# Out:
# [10, 20, 30, 40, 50]

# %%
lis1[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#Q11. write a code to create a tuple with the elements 10,20,30 and print it

# %%
tup = (10,20,30)
tup
# Out:
# (10, 20, 30)

# %%
#Q12. write a code to access the first element of the tuple("apple","banana","cherry")

# %%
tup = ("apple","banana","cherry")
tup
# Out:
# ('apple', 'banana', 'cherry')

# %%
tup[0]
# Out:
# 'apple'

# %%
#Q13. write a code to count how many times the number 2 appears in the tuple(1,2,3,2,4,2)

# %%
tup = (1,2,3,2,4,2)
tup
# Out:
# (1, 2, 3, 2, 4, 2)

# %%
tup.count(2)
# Out:
# 3

# %%
#Q14. write the code to find the index of the element"cat" in the tuple("dog","cat",rabbit")

# %%
tupl = ("dog","cat","rabbit")
tupl
# Out:
# ('dog', 'cat', 'rabbit')

# %%
tupl.index("cat")
# Out:
# 1

# %%
#15. write a code to check if the element "banana" is in the tuple("apple","orange","banana")

# %%
tupl1 = ("apple","orange","banana")
tupl1
# Out:
# ('apple', 'orange', 'banana')

# %%
"banana" in tupl1
# Out:
# True

# %%
#Q16. write a code to create a set with the elements 1,2,3,4,5 and print it

# %%
group = {1,2,3,4,5}
print(group)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(group)
# Out:
# set

# %%
#Q17. write a code to add the element 6 to the set {1,2,3,4}

# %%
set1 = {1,2,3,4}
set1
# Out:
# {1, 2, 3, 4}

# %%
set1.add(6)
set1
# Out:
# {1, 2, 3, 4, 6}

# %%
#Q18. write a code to create a tuple with the elements 10,20,30 and print it

# %%
tup = (10,20,30)
tup
# Out:
# (10, 20, 30)

# %%
#Q19. write a code to access the first element of the tuple("apple","banana","chery")

# %%
tup = ("apple","banana","chery")
tup
# Out:
# ('apple', 'banana', 'chery')

# %%
tup[0]
# Out:
# 'apple'

# %%
#Q20. write a code to count how many times the number 2 appears in the tuple(1,2,3,2,4,2)

# %%
tup1 = (1,2,3,2,4,2)
tup1
# Out:
# (1, 2, 3, 2, 4, 2)

# %%
tup1.count(2)
# Out:
# 3

# %%
#Q21. write a code to find a index of the element "cat" in the tuple ("dog","cat","rabbit")

# %%
tup2 = ("dog","cat","rabbit")
tup2
# Out:
# ('dog', 'cat', 'rabbit')

# %%
tup2.index("cat")
# Out:
# 1

# %%
#Q22. write a code to check if the element "banana" is in the tuple("apple","orange","banana")

# %%
tup2 = ("apple","orange","banana")
tup2
# Out:
# ('apple', 'orange', 'banana')

# %%
"banana" in tup2
# Out:
# True

# %%
#Q23. write a code to create a set with the elements 1,2,3,4,5 and print it

# %%
set1 = {1,2,3,4,5 }
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Q24. write a code to add the element 6 to the set {1,2,3,4}

# %%
set3 = {1,2,3,4}
set3
# Out:
# {1, 2, 3, 4}

# %%
set3.add(6)
set3
# Out:
# {1, 2, 3, 4, 6}
